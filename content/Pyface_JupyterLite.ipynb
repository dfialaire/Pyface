# %%
# %pip install -q ipywidgets
# %pip install -q numpy
# %pip install -q matplotlib

# %%
from Les_Fonctions_completes import *
from ipywidgets import widgets
os.chdir(Lieu)
affich_image("Logo2.jpg")

# %% [markdown]
# # Choix N° 1 :  Analyser une nouvelle photo pour enrichir la base de données

# %%
Analyse_une_nouvelle_photo()

# %% [markdown]
# # Choix N° 2 :  Analyser une série de photos pour enrichir la base de données

# %%
Analyse_une_serie_de_photo_enrichissement_Base_de_donnees()
# Out:
# ##############################################
#
#      --> Voici le résultat des analyses graphiques :
#  Liste des positions des lignes horizontales :  [0, 30, 68, 80, 86, 95, 119, 144, 147, 170, 188]
#   ==>  Voici la liste des distances (raccourcies par 3 ) entre les lignes horizontales :
#                  [1.0, 2.0, 3.0, 4.0, 6.0, 7.67, 8.0, 8.33, 12.67]
#                 : Cela constitue le matricule d'identification horizontal de cette photo.
#
#  Liste des positions des lignes verticales :  [2, 7, 14, 30, 38, 46, 50, 53, 61, 71, 87, 150, 153, 157, 161, 184]
#   ==>  Voici la liste des distances (raccourcies par 3 ) entre les lignes verticales :
#                  [1.0, 1.0, 1.33, 1.33, 1.33, 2.33, 2.67, 2.67, 2.67, 3.33, 5.33, 5.33, 7.67, 21.0]
#                 : Cela constitue le matricule d'identification vertical de cette photo.
# ##############################################
#
#      --> Voici le résultat des analyses graphiques :
# ...

# %% [markdown]
# # Choix N° 3 :  Visualiser-gérer la base de données de photos.

# %%
Visualiser_Gerer_Base_de_donnees()

# %% [markdown]
# # Choix N° 4 :  Utiliser la base de données pour comparer des photos.

# %%
Choix_Photo_de_base()
# Out:
# Baz_Donnees_Photos_lu =  [['ER2NB.jpg', [1.0, 2.0, 3.0, 4.0, 6.0, 7.67, 8.0, 8.33, 12.67], 'ER2NB_ligne.jpg', 3, 198, [1.0, 1.0, 1.33, 1.33, 1.33, 2.33, 2.67, 2.67, 2.67, 3.33, 5.33, 5.33, 7.67, 21.0], 'ER2NB_ligne_Vert.jpg', 3, 190], ['ER3NB.jpg', [1.0, 1.25, 1.75, 1.75, 2.5, 2.75, 3.0, 3.25, 3.75, 14.75], 'ER3NB_ligne.jpg', 4, 204, [1.0, 1.33, 1.33, 1.33, 2.67, 4.0, 4.33, 5.0, 5.33, 7.0, 7.33, 7.67, 12.0], 'ER3NB_ligne_Vert.jpg', 3, 204], ['ER5NB.jpg', [1.0, 2.67, 2.67, 3.0, 6.33, 6.33, 6.67, 7.0, 24.33], 'ER5NB_ligne.jpg', 3, 227, [1.0, 1.33, 1.67, 2.33, 3.0, 3.67, 4.0, 4.33, 4.33, 4.33, 4.67, 7.0, 8.0, 17.0], 'ER5NB_ligne_Vert.jpg', 3, 227], ['Kad1.png', [1.0, 2.0, 3.33, 5.67, 12.67, 17.67, 19.0], 'Kad1_ligne.jpg', 3, 200, [1.0, 1.25, 1.75, 2.25, 2.25, 2.5, 3.0, 3.5, 5.25, 5.75], 'Kad1_ligne_Vert.jpg', 4, 154], ['Kad3.png', [1.0, 2.0, 2.33, 2.33, 2.33, 3.0, 3.33, 4.33, 5.67, 5.67, 6.0, 6.0], 'Kad3_ligne.jpg', 3, 200, [1.0, 1.0, 1.0, 1.25, 1.25, 1.5, 1.75, 2.0, 2.25, 2.5, 3.5, 4.0
# ...

# %%
coucou
